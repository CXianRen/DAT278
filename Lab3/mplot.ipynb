# %%
import matplotlib.pyplot as plt

x = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.01]
# corresponding y axis values 
csr = [74.47863,54.718671,42.105422,33.452856,24.192321,17.081804,11.672333,7.869853,5.453233,0.08612]   
coo = [136.573992,113.018021,91.939034,73.292476,57.850499,43.059094,30.50688,19.953501,10.923495,0.550719]
dense = [6.852887,5.64885,4.707752,5.008105,4.623035,4.59087,4.559681,4.486073,4.456105,4.368214]
# plotting the points  
plt.plot(x, csr, label='csr') 
plt.plot(x, coo, label='coo')
plt.plot(x, dense, label='dense')

# naming the x axis 
plt.xlabel('dense') 
# naming the y axis 
plt.ylabel('energy') 
  
# function to show the plot 
plt.legend()
plt.show()
